# %%
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get("https://fortress.wa.gov/wsp/collisionanalysistool/Query/SearchCriteria")

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
data = {
    'ColliDateStart': '01/01/2015 00:00:00',
    'ColliDateEnd': '11/15/2025 00:00:00',
    'County' : 'Snohomish',
    'City' : 'Lake Stevens',
}

# %%
results = requests.post("https://fortress.wa.gov/wsp/collisionanalysistool/Query/SearchCriteria", data=data)

# %%
results
# Out:
# <Response [200]>

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select, WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
import time

# %%
driver = webdriver.Chrome()  # or Firefox()
driver.get("https://fortress.wa.gov/wsp/collisionanalysistool/Query/SearchCriteria")

# Wait for page to load
wait = WebDriverWait(driver, 10)

# Fill in form fields (you'll need to inspect the actual field names)
# Example:
date_from = driver.find_element(By.ID, "ColliDateStart")
date_from.send_keys("01/01/2015 00:00:00")

date_to = driver.find_element(By.ID, "ColliDateEnd")
date_to.send_keys("11/15/2025 00:00:00")

county_select = Select(driver.find_element(By.ID, "County"))
county_select.select_by_visible_text("Snohomish")

city_select = Select(driver.find_element(By.ID, "City"))
city_select.select_by_visible_text("Lake Stevens")

# Submit form
submit_button = driver.find_element(By.ID, "submit")
submit_button.click()

# Wait for results and extract data
time.sleep(5)
results = driver.find_element(By.ID, "resultsTable").text

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 driver = webdriver.Chrome()  # or Firefox()
#       2 driver.get("https://fortress.wa.gov/wsp/collisionanalysistool/Query/SearchCriteria")
#       4 # Wait for page to load
#
# File ~/anaconda3/envs/roundabout-env/lib/python3.14/site-packages/selenium/webdriver/chrome/webdriver.py:47, in WebDriver.__init__(self, options, service, keep_alive)
#      44 service = service if service else Service()
#      45 options = options if options else Options()
# ---> 47 super().__init__(
#      48     browser_name=DesiredCapabilities.CHROME["browserName"],
#      49     vendor_prefix="goog",
#      50     options=options,
#      51     service=service,
#      52     keep_alive=keep_alive,
#      53 )
#
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# This will automatically download and setup the correct chromedriver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get("https://fortress.wa.gov/wsp/collisionanalysistool/Query/SearchCriteria")
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[2], line 6
#       3 from webdriver_manager.chrome import ChromeDriverManager
#       5 # This will automatically download and setup the correct chromedriver
# ----> 6 driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
#       7 driver.get("https://fortress.wa.gov/wsp/collisionanalysistool/Query/SearchCriteria")
#
# File ~/anaconda3/envs/roundabout-env/lib/python3.14/site-packages/selenium/webdriver/chrome/webdriver.py:47, in WebDriver.__init__(self, options, service, keep_alive)
#      44 service = service if service else Service()
#      45 options = options if options else Options()
# ---> 47 super().__init__(
#      48     browser_name=DesiredCapabilities.CHROME["browserName"],
#      49     vendor_prefix="goog",
#      50     options=options,
#      51     service=service,
# ...
